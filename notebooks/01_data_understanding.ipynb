# %% [markdown]
# <a href="https://colab.research.google.com/github/ARizalma/river-water-quality-analysis/blob/main/01_data_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # River Water Quality Analysis
#
# ## Notebook 01 — Data Understanding

# %%
# Import Libraries

import pandas as pd
import numpy as np

# %%
# Load Dataset

import requests

url = "https://raw.githubusercontent.com/ARizalma/river-water-quality-analysis/main/Data/river-water-quality-data-for-2023.csv"

df = pd.read_csv(url, sep=";")
