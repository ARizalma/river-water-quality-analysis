# %% [markdown]
# <a href="https://colab.research.google.com/github/ARizalma/river-water-quality-analysis/blob/main/notebooks/01_data_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # River Water Quality Analysis
#
# ## Notebook 01 — Data Understanding

# %%
# Import Libraries

import pandas as pd
import numpy as np

# %%
# Load Dataset

import requests

url = "https://raw.githubusercontent.com/ARizalma/river-water-quality-analysis/main/Data/river-water-quality-data-for-2023.csv"

df = pd.read_csv(url, sep=";")

# %%
## Data Overview

df.head()
# Out:
#   titik_sampel lintang_selatan  bujur_timur jenis_parameter parameter  \
# 0        ANK-1    -6,175882376  106,7286948          Fisika       TDS
# 1        ANK-1    -6,175882376  106,7286948          FIsika       TSS
# 2        ANK-1    -6,175882376  106,7286948           Kimia        pH
# 3        ANK-1    -6,175882376  106,7286948           Kimia       BOD
# 4        ANK-1    -6,175882376  106,7286948           Kimia       COD
#
#   baku_mutu hasil_pengukuran  periode_data       periode_pemantauan  \
# 0      1000              164          2023  Periode 1 (Musim Hujan)
# 1        50               24          2023  Periode 1 (Musim Hujan)
# 2       6-9             7,56          2023  Periode 1 (Musim Hujan)
# 3         3            23,65          2023  Periode 1 (Musim Hujan)
# 4        25              189          2023  Periode 1 (Musim Hujan)
#
#    bulan_sampling nama_sungai                      alamat
# 0               2       Angke  Jl. Duri Kosambi (Ciledug)
# ...
